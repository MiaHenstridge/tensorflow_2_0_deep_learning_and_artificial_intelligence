# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D
from tensorflow.keras.models import Model

# %% [markdown]
# ## Load in data

# %%
cifar_10 = tf.keras.datasets.cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar_10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 600s 4us/step

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
x_train.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1))

# %%
y_train, y_test = y_train.flatten(), y_test.flatten()

# %%
x_train.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000,))

# %%
# number of classes
K = len(set(y_train))
K
# Out:
# 10

# %% [markdown]
# ## Build the model

# %%
i = Input(shape=x_train[0].shape)
x = Conv2D(filters=32, kernel_size=(3,3), strides=2, activation='relu')(i)
x = Conv2D(filters=64, kernel_size=(3,3), strides=2, activation='relu')(x)
x = Conv2D(filters=128, kernel_size=(3,3), strides=2, activation='relu')(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(units=1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(units=K, activation='softmax')(x)

model = Model(inputs=i, outputs=x)

# %% [markdown]
# ## Compile and fit the model

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 132s 84ms/step - loss: 1.5519 - accuracy: 0.4341 - val_loss: 1.2727 - val_accuracy: 0.5478
# Epoch 2/15
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2627 - accuracy: 0.5477 - val_loss: 1.1093 - val_accuracy: 0.6017
# Epoch 3/15
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.1353 - accuracy: 0.5950 - val_loss: 1.0405 - val_accuracy: 0.6292
# Epoch 4/15
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0353 - accuracy: 0.6304 - val_loss: 1.0277 - val_accuracy: 0.6399
# Epoch 5/15
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9566 - accuracy: 0.6579 - val_loss: 0.9478 - val_accuracy: 0.6726
# Epoch 6/15
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.8923 - accuracy: 0.6848 - val_loss: 0.9128 - val_accuracy: 0.6810
# Epoch 7/15
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.8391 - accuracy: 0.7003 - val_loss: 0.9028 - val_accuracy: 0.6815
# Epoch 8/15
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.7923 - accuracy: 0.7183 - val_loss: 0.8330 - val_accuracy: 0.7105
# Epoch 9/15
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.7616 - accuracy: 0.7297 - val_loss: 0.8694 - val_accuracy: 0.7023
# Epoch 10/15
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.7221 - accuracy: 0.7434 - val_loss: 0.8132 - val_accuracy: 0.7206
# Epoch 11/15
# 1563/1563 [==============================] - 12s 7ms/step - loss: 0.6940 - accuracy: 0.7519 - val_loss: 0.8165 - val_accuracy: 0.7167
# Epoch 12/15
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6678 - accuracy: 0.7616 - val_loss: 0.8274 - val_accuracy: 0.7168
# Epoch 13/15
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6432 - accuracy: 0.7687 - val_loss: 0.8139 - val_accuracy: 0.7199
# Epoch 14/15
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6280 - accuracy: 0.7758 - val_loss: 0.8435 - val_accuracy: 0.7144
# Epoch 15/15
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6106 - accuracy: 0.7835 - val_loss: 0.7988 - val_accuracy: 0.7242

# %% [markdown]
# ## Plot loss per iteration

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %% [markdown]
# ## Plot accuracy per iteration

# %%
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()

# %% [markdown]
# ## Plot confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
  else:
      print('Confusion matrix, without normalization')

  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

# %%
p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Confusion matrix, without normalization
# [[701  16  38  18  24   9  16  10 125  43]
#  [ 13 840   4   2   6   5  11   1  30  88]
#  [ 62   6 583  61 106  58  71  29  18   6]
#  [  9  11  67 503  72 179  94  32  16  17]
#  [ 22   4  48  57 699  48  50  54  11   7]
#  [ 11   7  45 166  49 634  34  39   6   9]
#  [  6   9  28  49  36  21 826   7   7  11]
#  [ 12   4  27  46  56  62   8 760   6  19]
#  [ 45  21  10  13   6   1   8   6 866  24]
#  [ 19  68  11   8   5   7  12  13  27 830]]

# %% [markdown]
# ## Label mapping

# %%
# label mapping
labels = '''airplane
automobile
bird
cat
deer
dog
frog
horse
ship
truck'''.split()

# %% [markdown]
# ## Show some misclassified examples

# %%
# Show some misclassified examples
# TODO: add label names
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i], cmap='gray')
plt.title("True label: %s Predicted: %s" % (labels[y_test[i]], labels[p_test[i]]));

# %%
model.built
# Out:
# True

# %%
# Save model
model.save('cifar10_v1.h5')
