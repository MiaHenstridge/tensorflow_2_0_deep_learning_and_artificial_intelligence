# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model

# %% [markdown]
# ## Load in data

# %%
cifar10 = tf.keras.datasets.cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train, x_test = x_train/255.0, x_test/255.0
y_train, y_test = y_train.flatten(), y_test.flatten()

# %%
x_train.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000,))

# %%
# number of classes
K = len(set(y_train))

# %%
K
# Out:
# 10

# %% [markdown]
# ## Build the model using functional API

# %%
i = Input(shape=x_train[0].shape)

x = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)

x = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)

x = Dropout(0.2)(x)

x = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)

x = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)

x = Dropout(0.2)(x)

x = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)

x = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)

x = Dropout(0.2)(x)

# x = GlobalMaxPooling2D()(x)

x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(K, activation='softmax')(x)

model = Model(i, x)

# %% [markdown]
# ## Compile and fit model

# %%
# Compile
# Note: make sure you are using the GPU for this!
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit - without augmentation
r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 66s 42ms/step - loss: 1.3762 - accuracy: 0.5267 - val_loss: 1.0105 - val_accuracy: 0.6518
# Epoch 2/50
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.9329 - accuracy: 0.6744 - val_loss: 0.8449 - val_accuracy: 0.7024
# Epoch 3/50
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.7920 - accuracy: 0.7273 - val_loss: 0.7774 - val_accuracy: 0.7380
# Epoch 4/50
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.6988 - accuracy: 0.7603 - val_loss: 0.6454 - val_accuracy: 0.7823
# Epoch 5/50
# 1563/1563 [==============================] - 66s 43ms/step - loss: 0.6261 - accuracy: 0.7870 - val_loss: 0.6206 - val_accuracy: 0.7898
# Epoch 6/50
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.5668 - accuracy: 0.8069 - val_loss: 0.6116 - val_accuracy: 0.7941
# Epoch 7/50
# 1563/1563 [==============================] - 68s 43ms/step - loss: 0.5121 - accuracy: 0.8246 - val_loss: 0.5794 - val_accuracy: 0.8064
# Epoch 8/50
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.4733 - accuracy: 0.8357 - val_loss: 0.5733 - val_accuracy: 0.8139
# Epoch 9/50
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.4353 - accuracy: 0.8501 - val_loss: 0.8550 - val_accuracy: 0.7193
# Epoch 10/50
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.3949 - accuracy: 0.8643 - val_loss: 0.5395 - val_accuracy: 0.8289
# Epoch 11/50
# 1563/1563 [==============================] - 68s 44ms/step - loss: 0.3598 - accuracy: 0.8743 - val_loss: 0.5303 - val_accuracy: 0.8299
# Epoch 12/50
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.3320 - accuracy: 0.8850 - val_loss: 0.5317 - val_accuracy: 0.8337
# Epoch 13/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.3103 - accuracy: 0.8928 - val_loss: 0.4917 - val_accuracy: 0.8403
# Epoch 14/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.2831 - accuracy: 0.9022 - val_loss: 0.5318 - val_accuracy: 0.8297
# Epoch 15/50
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.2627 - accuracy: 0.9080 - val_loss: 0.5693 - val_accuracy: 0.8279
# Epoch 16/50
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.2428 - accuracy: 0.9164 - val_loss: 0.5394 - val_accuracy: 0.8368
# Epoch 17/50
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.2300 - accuracy: 0.9203 - val_loss: 0.5291 - val_accuracy: 0.8392
# Epoch 18/50
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.2163 - accuracy: 0.9262 - val_loss: 0.5196 - val_accuracy: 0.8504
# Epoch 19/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.2025 - accuracy: 0.9307 - val_loss: 0.5314 - val_accuracy: 0.8397
# Epoch 20/50
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.1897 - accuracy: 0.9346 - val_loss: 0.5343 - val_accuracy: 0.8512
# Epoch 21/50
# 1563/1563 [==============================] - 62s 39ms/step - loss: 0.1823 - accuracy: 0.9383 - val_loss: 0.5326 - val_accuracy: 0.8504
# Epoch 22/50
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.1735 - accuracy: 0.9395 - val_loss: 0.5957 - val_accuracy: 0.8410
# Epoch 23/50
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.1652 - accuracy: 0.9428 - val_loss: 0.5554 - val_accuracy: 0.8458
# Epoch 24/50
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.1571 - accuracy: 0.9446 - val_loss: 0.5349 - val_accuracy: 0.8449
# Epoch 25/50
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.1512 - accuracy: 0.9484 - val_loss: 0.5431 - val_accuracy: 0.8532
# Epoch 26/50
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.1476 - accuracy: 0.9492 - val_loss: 0.5589 - val_accuracy: 0.8480
# Epoch 27/50
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.1405 - accuracy: 0.9518 - val_loss: 0.5494 - val_accuracy: 0.8495
# Epoch 28/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.1419 - accuracy: 0.9516 - val_loss: 0.5657 - val_accuracy: 0.8524
# Epoch 29/50
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.1297 - accuracy: 0.9559 - val_loss: 0.6120 - val_accuracy: 0.8398
# Epoch 30/50
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.1272 - accuracy: 0.9561 - val_loss: 0.5871 - val_accuracy: 0.8435
# Epoch 31/50
# 1563/1563 [==============================] - 62s 39ms/step - loss: 0.1280 - accuracy: 0.9574 - val_loss: 0.6056 - val_accuracy: 0.8507
# Epoch 32/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.1218 - accuracy: 0.9592 - val_loss: 0.5377 - val_accuracy: 0.8495
# Epoch 33/50
# 1563/1563 [==============================] - 62s 39ms/step - loss: 0.1195 - accuracy: 0.9597 - val_loss: 0.5628 - val_accuracy: 0.8497
# Epoch 34/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.1147 - accuracy: 0.9620 - val_loss: 0.5675 - val_accuracy: 0.8543
# Epoch 35/50
# 1563/1563 [==============================] - 60s 39ms/step - loss: 0.1140 - accuracy: 0.9620 - val_loss: 0.6287 - val_accuracy: 0.8386
# Epoch 36/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.1080 - accuracy: 0.9639 - val_loss: 0.6925 - val_accuracy: 0.8404
# Epoch 37/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.1087 - accuracy: 0.9630 - val_loss: 0.5716 - val_accuracy: 0.8555
# Epoch 38/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.1047 - accuracy: 0.9645 - val_loss: 0.5548 - val_accuracy: 0.8537
# Epoch 39/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.1005 - accuracy: 0.9668 - val_loss: 0.6161 - val_accuracy: 0.8478
# Epoch 40/50
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.1007 - accuracy: 0.9656 - val_loss: 0.5980 - val_accuracy: 0.8507
# Epoch 41/50
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.0993 - accuracy: 0.9670 - val_loss: 0.5599 - val_accuracy: 0.8462
# Epoch 42/50
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.0939 - accuracy: 0.9690 - val_loss: 0.5988 - val_accuracy: 0.8546
# Epoch 43/50
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.0976 - accuracy: 0.9682 - val_loss: 0.6504 - val_accuracy: 0.8525
# Epoch 44/50
# 1563/1563 [==============================] - 63s 41ms/step - loss: 0.0941 - accuracy: 0.9690 - val_loss: 0.6101 - val_accuracy: 0.8483
# Epoch 45/50
# 1563/1563 [==============================] - 63s 41ms/step - loss: 0.0900 - accuracy: 0.9700 - val_loss: 0.6415 - val_accuracy: 0.8479
# Epoch 46/50
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.0889 - accuracy: 0.9709 - val_loss: 0.6032 - val_accuracy: 0.8535
# Epoch 47/50
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.0904 - accuracy: 0.9697 - val_loss: 0.5957 - val_accuracy: 0.8549
# Epoch 48/50
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.0827 - accuracy: 0.9719 - val_loss: 0.6072 - val_accuracy: 0.8536
# Epoch 49/50
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.0857 - accuracy: 0.9718 - val_loss: 0.6286 - val_accuracy: 0.8590
# Epoch 50/50
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.0873 - accuracy: 0.9714 - val_loss: 0.6206 - val_accuracy: 0.8543

# %%
# # Fit with data augmentation
# # Note: if you run this AFTER calling the previous model.fit(), it will CONTINUE training where it left off
# batch_size = 32
# data_generator = tf.keras.preprocessing.image.ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
# train_generator = data_generator.flow(x_train, y_train, batch_size)
# steps_per_epoch = x_train.shape[0] // batch_size
# r = model.fit(train_generator, validation_data=(x_test, y_test), steps_per_epoch=steps_per_epoch, epochs=50)

# %% [markdown]
# ## Plot loss per iteration

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %% [markdown]
# ## Plot accuracy per iteration

# %%
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()

# %% [markdown]
# ## Plot confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
  else:
      print('Confusion matrix, without normalization')

  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

# %%
p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# 313/313 [==============================] - 4s 12ms/step
# Confusion matrix, without normalization
# [[901   9  23  10   5   6   2   7  24  13]
#  [  5 946   3   3   3   3   2   0   6  29]
#  [ 44   0 745  44  52  49  43  13   9   1]
#  [ 12   2  29 664  38 169  40  30  10   6]
#  [  9   3  28  38 862  18  14  25   3   0]
#  [  5   0  14  70  29 836  10  31   1   4]
#  [  5   3  20  54  14  16 880   4   3   1]
#  [  6   1  16  13  30  22   1 904   1   6]
#  [ 46  25   6   9   1   1   4   3 892  13]
#  [ 10  48   1   7   2   3   3   6   7 913]]

# %% [markdown]
# ## Label mapping

# %%
# label mapping
labels = '''airplane
automobile
bird
cat
deer
dog
frog
horse
ship
truck'''.split()

# %% [markdown]
# ## Show some misclassified examples

# %%
# Show some misclassified examples
# TODO: add label names
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i], cmap='gray')
plt.title("True label: %s Predicted: %s" % (labels[y_test[i]], labels[p_test[i]]));

# %%
model.built
# Out:
# True

# %%
# Now that the model is so large, it's useful to summarize it
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 32)        896
#
#  batch_normalization_5 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_6 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_7 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_8 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_9 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_10 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_4 (Dropout)         (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_5 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 2,397,226
# Trainable params: 2,396,330
# Non-trainable params: 896
# _________________________________________________________________

# %%
# Save model
model.save('cifar10_v2.h5')
